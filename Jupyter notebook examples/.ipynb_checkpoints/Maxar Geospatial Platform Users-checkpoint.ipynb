# %% [markdown]
# ## Users

# %% [markdown]
# #### The following functionality is intended for account administrators and will not work with base user permissions

# %% [markdown]
# #### Initialize the Maxar Geospatial Platform SDK Module

# %%
from MGP_SDK.interface import Interface

try:
  interface = Interface() # if .MGP-config was created
except:
  interface = Interface('<user_name>','<user_password>', '<user_client_id>') # if .MGP-config was not created

# %% [markdown]
# #### Initialize the users portion of the account-services class for Maxar Geospatial Platform SDK

# %%
mgp_users = interface.account_service.users

# %% [markdown]
# #### List all users within an account
# The following command will return dictionary with all of the information of the user or users that are tied to the user's account

# %%
my_users = mgp_users.get_users()
print(my_users)
# Out:
# {'users': [{'userId': 'f:63a7af62-7902-4925-9382-3d920450a524:1', 'username': 'system-admin-swonline@maxar.com', 'firstName': 'System', 'lastName': 'SW_ONLINE', 'emailAddress': 'system-admin-swonline@maxar.com', 'createdDate': '2022-10-29T21:33:22.944124Z', 'updatedDate': '2023-02-15T16:31:28.808809Z', 'isActive': False, 'emailVerified': True, 'password': None, 'userType': 'SYSTEM_ADMIN', 'accountId': None, 'account': None, 'activations': [], 'country': 'Canada', 'phone': '+12817251014', 'suspensionReason': 'Failed Login Attempts', 'notifySuspension': False, 'status': 'SUSPENDED', 'totalCreditsUsed': 0.0, 'dailyCreditLimitTotal': -1, 'dailyCreditLimitUsed': 0}, {'userId': 'f:63a7af62-7902-4925-9382-3d920450a524:2', 'username': 'greg.murray@maxar.com', 'firstName': 'Greg', 'lastName': 'Murray', 'emailAddress': 'greg.murray@maxar.com', 'createdDate': '2022-10-30T17:16:26.367265Z', 'updatedDate': '2023-04-13T16:53:25.355543Z', 'isActive': True, 'emailVerified': True, 'password': None, 'userType': 'SYSTEM_ADMIN', 'accountId': 2, 'account': {'id': 2, 'accountNumber': 'ACC-725-858', 'name': 'Maxar Internal - Okta', 'sapLicenseId': '', 'soldTo': 'Maxar', 'licensee': 'Maxar', 'accountType': {'id': 15000, 'name': 'INTERNAL', 'description': 'Internal', 'createDate': '2022-10-29T20:20:26.952+00:00', 'updateDate': '2022-10-29T20:20:26.952+00:00'}, 'isActive': True, 'address': {'id': 3, 'streetAddress1': '1300 W 120th Avenue', 'streetAddress2': '', 'city': 'Westminster', 'country': 'United States', 'state': 'CO', 'postalCode': '80234', 'phone': None, 'createdDate': '2022-10-29T21:33:25.665723Z', 'updatedDate': '2023-05-10T15:27:40.263414Z'}, 'pointsOfContact': None, 'comments': None, 'createdDate': '2022-10-29T21:33:25.666904Z', 'updatedDate': '2023-05-10T15:27:40.266174Z'}, 'activations': [{'id': 523, 'activationNumber': 'ACT-4919007', 'accountId': 2, 'name': None, 'creatorName': None, 'startDate': '2022-01-01T00:00:00.000+00:00', 'endDate': None, 'activationType': {'id': 15002, 'name': 'EVALUATION', 'description': 'Evaluation', 'createDate': '2022-10-29T20:20:26.986+00:00', 'updateDate': '2022-10-29T20:20:26.986+00:00'}, 'notes': None, 'sapContractIdentifier': '1234567890', 'sapLineItem': '999999', 'isActive': True, 'createdDate': '2023-04-11T23:00:45.664453Z', 'updatedDate': '2023-04-13T02:00:32.152108Z', 'roles': None, 'purchasedRoles': None, 'creditLimit': -1, 'rateTableId': 115, 'totalCreditsUsed': 12.5923319747671, 'creditsUsedPercentage': -1.0, 'imageryHoldbackValue': 0, 'userLimit': -1, 'dailyCreditLimitTotal': -1, 'dailyCreditLimitUsed': 2.252666426822639, 'clientContextId': 'b4e8d573-56ee-4e79-abcd-7b161f93ea17'}], 'country': 'United States', 'phone': '3038622949', 'suspensionReason': None, 'notifySuspension': False, 'status': 'ACTIVE', 'totalCreditsUsed': 8.07706628646702, 'dailyCreditLimitTotal': -1, 'dailyCreditLimitUsed': 0}, {'userId': 'f:63a7af62-7902-4925-9382-3d920450a524:5', 'username': 'ross.anderson@maxar.com', 'firstName': 'Ross', 'lastName': 'Anderson', 'emailAddress': 'ross.anderson@maxar.com', 'createdDate': '2022-10-30T21:50:14.826253Z', 'updatedDate': '2023-05-10T15:23:20.620067Z', 'isActive': True, 'emailVerified': True, 'password': None, 'userType': 'GLOBAL_ADMIN', 'accountId': 2, 'account': {'id': 2, 'accountNumber': 'ACC-725-858', 'name': 'Maxar Internal - Okta', 'sapLicenseId': '', 'soldTo': 'Maxar', 'licensee': 'Maxar', 'accountType': {'id': 15000, 'name': 'INTERNAL', 'description': 'Internal', 'createDate': '2022-10-29T20:20:26.952+00:00', 'updateDate': '2022-10-29T20:20:26.952+00:00'}, 'isActive': True, 'address': {'id': 3, 'streetAddress1': '1300 W 120th Avenue', 'streetAddress2': '', 'city': 'Westminster', 'country': 'United States', 'state': 'CO', 'postalCode': '80234', 'phone': None, 'createdDate': '2022-10-29T21:33:25.665723Z', 'updatedDate': '2023-05-10T15:27:40.263414Z'}, 'pointsOfContact': None, 'comments': None, 'createdDate': '2022-10-29T21:33:25.666904Z', 'updatedDate': '2023-05-10T15:27:40.26 ...

# %% [markdown]
# If the user knows the specific user id or username for a user, that can be passed into the get_users function to return the information on that specific user. NOTE: The activation id is not the activation number. The activation id is the identifier within the database.

# %%
my_users = mgp_users.get_users(user_id="<desired-user_id>")
print(my_users)

# %%
my_users = mgp_users.get_users(username="<desired-username>")
print(my_users)

# %% [markdown]
# #### Searching users
# In some cases there may be multiple users tied to an account. In this example, a user can see how to search through users with vague search terms in order to narrow down which activaiton is desired. Search terms can be usernames, roles, etc.

# %%
my_search = mgp_users.search("Bob")
print(my_search)

# %% [markdown]
# #### Creating a user
# An account admin has the ability to create, update, and delete new users for their account. The following example will demonstrate how to set up a base user, update the user, and delete the user. We will set some variables prior to running the command to make it more readable.

# %%
user = "BASE_USER"
acctId = "<you_account_id>"
activId = "<your_activation_id>"
email = "Bob@test.com"
first = "Bob"
last = "Smith"
country = "United States of America"

new_user = mgp_users.create_user(user, acctId, activId, email, first, last, country)
print(new_user)

# %% [markdown]
# #### Updating a user
# NOTE: The account the user is tied to and the type of user cannot be edited.

# %% [markdown]
# Firstly, we will search for the desired user's user_id, as this is needed to make the call work.

# %%
user = mgp_users.search("Bob")['users'][0]['userId']
print(user)

# %% [markdown]
# Now we will change the desired variable

# %%
new_first = "John"

update_user = mgp_users.update_user(user_id=user, firstName=new_first)
print(update_user)

# %% [markdown]
# #### Deleting a user
# To delete a user, pass in the user's id into the delete function

# %%
delete_user = mgp_users.delete_user(user)
print(delete_user)
